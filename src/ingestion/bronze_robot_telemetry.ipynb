# %%
raw_path = "abfss://raw@stautofulfildata.dfs.core.windows.net/robot_telemetry/"

# %%
df = spark.read.option("header", True).csv(raw_path)

# %%
df.display()

# %%
from pyspark.sql.functions import *
df = df.withColumn("ingestion_timestamp", current_timestamp()).withColumn("Source_file", col("_metadata.file_path")).withColumn("load_date", current_date())

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS bronze")

# %%
df = spark.read \
    .option("header", True) \
    .csv(raw_path)

df = df.withColumn(
        "ingestion_timestamp",
        current_timestamp()
    ) \
    .withColumn(
        "source_file",
        col("_metadata.file_path")
    ) \
    .withColumn(
        "load_date",
        current_date()
    )

(df.write
 .format("delta")
 .mode("append")
 .partitionBy("load_date")
 .saveAsTable("bronze.robot_telemetry"))

# %%
# %sql
SELECT COUNT (*) FROM bronze.robot_telemetry

# %%
# %sql
SELECT * FROM bronze.robot_telemetry
LIMIT 10
